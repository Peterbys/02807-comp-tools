# %% [markdown]
# Week 2:

# %%
import urllib.request
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/patrickcording/02807-comp-tools/master/docker/work/data/titanic.csv'
urllib.request.urlretrieve(url, 'titanic.csv')
# Out:
# ('titanic.csv', <http.client.HTTPMessage at 0x1f97c8fccc0>)

# %%
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1     False       3
# 1              2      True       1
# 2              3      True       3
# 3              4      True       1
# 4              5     False       3
# 5              6     False       3
# 6              7     False       1
# 7              8     False       3
# 8              9      True       3
# 9             10      True       2
# 10            11      True       3
# 11            12      True       1
# 12            13     False       3
# 13            14     False       3
# 14            15     False       3
# 15            16      True       2
# 16            17     False       3
# 17            18      True       2
# 18            19     False       3
# 19            20      True       3
# 20            21     False       2
# 21            22      True       2
# 22            23      True       3
# 23            24      True       1
# 24            25     False       3
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived          bool
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
bb = data.Survived[data.Survived == True]

# %%
data[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
data[['Sex', 'Survived','Pclass']].groupby(['Sex','Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Pclass  Survived
# 0  female       1  0.968085
# 1  female       2  0.921053
# 2  female       3  0.500000
# 3    male       1  0.368852
# 4    male       2  0.157407
# 5    male       3  0.135447

# %%
data[['Embarked','Survived']].groupby(['Embarked']).mean()
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %%
plt.bar(data.
# Out:
#   File "<ipython-input-86-282a95fe9ca2>", line 1
#     plt.bar(data.
#                  ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.hist(data[data.Survived == True].dropna().Age)
# Out:
# (array([ 8.,  6., 25., 21., 30., 12., 14.,  6.,  0.,  1.]),
#  array([ 0.92 ,  8.828, 16.736, 24.644, 32.552, 40.46 , 48.368, 56.276,
#         64.184, 72.092, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2      True       1
# 2              3      True       3
# 3              4      True       1
# 8              9      True       3
# 9             10      True       2
# 10            11      True       3
# 11            12      True       1
# 15            16      True       2
# 17            18      True       2
# 19            20      True       3
# 21            22      True       2
# 22            23      True       3
# 23            24      True       1
# 25            26      True       3
# 28            29      True       3
# 31            32      True       1
# 32            33      True       3
# 36            37      True       3
# 39            40      True       3
# 43            44      True       2
# 44            45      True       3
# 47            48      True       3
# 52            53      True       1
# 53            54      True       2
# 55            56      True       1
# ...

# %%
data[(data.Sex == 'male' & True)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-9ae5460db384> in <module>
# ----> 1 data[(data.Sex == 'male' & True)]
#
# TypeError: unsupported operand type(s) for &: 'str' and 'bool'
